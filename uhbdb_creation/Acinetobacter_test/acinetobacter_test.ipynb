# %%
import polars as pl

achromobacter_meta = pl.read_csv('/mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/uhbdb_creation/uhbdb_2026_03_05/Acinetobacter/Acinetobacter.metadata.tsv.gz', separator='\t')

# %%
achromobacter_meta.group_by('cluster').len().sort('len', descending=True)

# %%
cluster_id = achromobacter_meta.group_by('cluster').len().sort('len', descending=True)[0,0]

# %%
achromobacter_meta.filter(pl.col('cluster') == cluster_id)[['sample']].write_csv('acinetobacter_test_samples.txt', separator='\t', include_header=False)

# %%
# %%bash
# datasets download genome accession --inputfile acinetobacter_test_samples.txt
# unzip ncbi_dataset.zip
#
# skani triangle \
#     /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/uhbdb_creation/Acinetobacter_test/ncbi_dataset/data/*/*_genomic.fna \
#     --ci \
#     --full-matrix \
#     --slow \
#     -o acinetobacter_test_skani.tsv
