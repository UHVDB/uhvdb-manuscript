# %%
# %%bash
# for i in "3334" "3451" "3454" "3521" "3594" "3681" "3734" "3764" "3854" "3941" "3944" "3951" "3964" "4001" "4014" "4281" "4284"; do
#     micromamba activate lgonsa
#
#     csvtk cut \
#         --tabs \
#         -f Contig /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/liang_${i}_unenriched.coverm.tsv \
#         -o /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/liang_${i}_unenriched.contained_genomes.txt
#
#     seqkit grep \
#         /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/uhvdb_final_files/r2025_10/uhvdb_votu_reps.fna \
#         --pattern-file /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/liang_${i}_unenriched.contained_genomes.txt \
#         -o /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/liang_${i}_unenriched.contained_genomes.fna
#
#     micromamba activate pharokka
#
#     pharokka.py \
#         -g prodigal-gv \
#         --meta \
#         -i /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/liang_${i}_unenriched.contained_genomes.fna \
#         -o /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/pharokka \
#         -d /gscratch/stf/carsonjm/pharokka_db/ \
#         -t 32 \
#         --fast \
#         --skip_extra_annotations \
#         --skip_mash \
#         --keep_raw_prodigal
#
#     mv /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/pharokka/prodigal-gv_raw.ffn \
#         /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/pharokka/prodigal-gv_raw.fna
#
#     # fix read names in bam file
#     micromamba activate strobealign
#     samtools view \
#         -h /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/liang_${i}_unenriched.bam/liang_${i}_unenriched.contained_genomes.fna.gz.*_R1.deacon.fastq.gz.bam | \
#     awk 'BEGIN{OFS="\t"} {if ($1 ~ /^@/) { print $0 } else { sub(/\.[^.]*$/, "", $1); print $0 } }' \
#     | samtools view \
#         -b \
#         -o /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/liang_${i}_unenriched.bam/liang_${i}_unenriched.contained_genomes.fna.gz.renamed.bam
#
#     inStrain profile \
#         /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/liang_${i}_unenriched.bam/liang_${i}_unenriched.contained_genomes.fna.gz.renamed.bam \
#         /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/uhvdb_final_files/r2025_10/uhvdb_votu_reps.fna \
#         -o /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/instrain \
#         --processes 32 \
#         --min_read_ani 0.92 \
#         --min_cov 5 \
#         --skip_genome_wide \
#         --skip_plot_generation \
#         --gene_file /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_${i}/liang_${i}_unenriched/coverm/contig/pharokka/prodigal-gv_raw.fna
# done
# Out:
# critical libmamba Shell not initialized
# 'micromamba' is running as a subprocess and can't modify the parent shell.
# Thus you must initialize your shell before using activate and deactivate.
#
# To initialize the current bash shell, run:
#     $ eval "$(micromamba shell hook --shell bash)"
# and then activate or deactivate with:
#     $ micromamba activate
# To automatically initialize all future (bash) shells, run:
#     $ micromamba shell init --shell bash --root-prefix=~/.local/share/mamba
# If your shell was already initialized, reinitialize your shell with:
#     $ micromamba shell reinit --shell bash
# Otherwise, this may be an issue. In the meantime you can run commands. See:
#     $ micromamba run --help
#
# Supported shells are {bash, zsh, csh, posix, xonsh, cmd.exe, powershell, fish, nu}.
# The history saving thread hit an unexpected error (OperationalError('disk I/O error')).History will not be written to the database.
# [INFO] 74 patterns loaded from file
# ...

# %%
# %%bash
#
# # fix read names in bam file
# samtools view -h /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/coverm/contig/liang_100_unenriched.bam/liang_100_unenriched.contained_genomes.fna.gz.SRR9670878_R1.deacon.fastq.gz.bam | \
# awk 'BEGIN{OFS="\t"} {
#     if ($1 ~ /^@/) { print $0 }          # keep header lines
#     else { sub(/\.[^.]*$/, "", $1); print $0 }
# }' | samtools view -b -o renamed.bam

# %%
# !inStrain profile \
    /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/renamed.bam \
    /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/uhvdb_final_files/r2025_10/uhvdb_votu_reps.fna \
    -o /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/instrain \
    --processes 32 \
    --min_read_ani 0.92 \
    --min_cov 5 \
    --skip_genome_wide \
    --skip_plot_generation \
    --gene_file /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/coverm/contig/pharokka/prodigal-gv_raw.fna

# %%
# %%bash
#
# zcat /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/strobealign/liang_100_unenriched.virus_genomes.fna.gz \
#     > /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/strobealign/liang_100_unenriched.virus_genomes.fna
#
# spacerextractor create_target_db \
#     -i /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/coverm/contig/liang_100_unenriched.contained_genomes.fna \
#     -d /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/coverm/contig/reference_spacerextractor_db \
#     -t 32
#
# spacerextractor map_to_target \
#     -i /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/crispr_spacers.fna \
#     -d /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/coverm/contig/reference_spacerextractor_db \
#     -o /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/coverm/contig/spacerextractor_hits \
#     -t 32

# %%
# %%bash
#
# reformat.sh \
#     in1=/mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/assemble/prjna524703/liang_100/liang_100_unenriched/readdownload/SRR9670878_R1.deacon.fastq.gz \
#     in2=/mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/assemble/prjna524703/liang_100/liang_100_unenriched/readdownload/SRR9670878_R2.deacon.fastq.gz \
#     out=/mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/assemble/prjna524703/liang_100/liang_100_unenriched/readdownload/SRR9670878.interleaved.fastq.gz
#
# spacerextractor \
#     extract_spacers \
#     -d /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/spacerextractor_db/SE_Db_r214GBIMG_0.9/ \
#     -o /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/assemble/prjna524703/liang_100/liang_100_unenriched/readdownload/spacerextractor_results/ \
#     -f /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/assemble/prjna524703/liang_100/liang_100_unenriched/readdownload/SRR9670878.interleaved.fastq.gz \
#     -t 32
#
# spacerextractor \
#     filter_hq_spacers \
#     -d /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/spacerextractor_db/SE_Db_r214GBIMG_0.9/ \
#     -w /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/assemble/prjna524703/liang_100/liang_100_unenriched/readdownload/spacerextractor_results/ \
#     -t 32
#
# spacerextractor map_to_target \
#     -i /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/assemble/prjna524703/liang_100/liang_100_unenriched/readdownload/spacerextractor_results/Final_spacers.nr.denoised.hq.fna \
#     -d /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/coverm/contig/reference_spacerextractor_db \
#     -o /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/coverm/contig/read_spacers_to_ref_hits \
#     -t 32
#
# spacerextractor map_to_target \
#     -i /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/assemble/prjna524703/liang_100/liang_100_unenriched/readdownload/spacerextractor_results/Final_spacers.nr.denoised.hq.fna \
#     -d /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/TEST_viruses_db \
#     -o /mmfs1/gscratch/pedslabs_hoffman/carsonjm/CFPhageome/repos/uhvdb-manuscript/figure_s10/enriched_virome_test/results/uhvdb/analyze/prjna524703/liang_100/liang_100_unenriched/coverm/contig/read_spacers_to_assembly_hits \
#     -t 32
